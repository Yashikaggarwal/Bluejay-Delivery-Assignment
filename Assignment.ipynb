# %%
import pandas as pd

def load_timecard(file_path):
    """ This function loads the timecard data from the Excel file given."""
    
    # Load the Excel file into a pandas DataFrame
    df = pd.read_excel(file_path)
    
    # Assuming that the 'Time' and 'Time Out' columns are in datetime format
    df['Time'] = pd.to_datetime(df['Time'])
    df['Time Out'] = pd.to_datetime(df['Time Out'])
    
    # Sort the DataFrame by employee name and time to facilitate analysis
    df.sort_values(by=['Employee Name', 'Time'], inplace=True)
    
    return df

def calculate_consecutive_days(prev_time, current_time):
    """ Calculate if the current time is part of a consecutive workday."""
    # Check if the current row is part of a consecutive workday
    if prev_time is None or (current_time - prev_time).days == 1:
        return True
    return False

def analyze_timecard_row(prev_time, current_time, current_employee, current_position):
    """
    Analyze a row of the timecard and print relevant information.

    Parameters:
    - prev_time (pd.Timestamp or None): Previous time.
    - current_time (pd.Timestamp): Current time.
    - current_employee (str): Employee name.
    - current_position (str): Employee position.
    """
    # Check if the current row is part of a consecutive workday
    if calculate_consecutive_days(prev_time, current_time):
        print(f"{current_employee} ({current_position}) has worked for 7 consecutive days.")
    
    time_between_shifts = (current_time - prev_time).seconds / 3600 if prev_time else 0
    if 1 < time_between_shifts < 10:
        print(f"{current_employee} ({current_position}) has less than 10 hours between shifts but more than 1 hour.")
    
    shift_duration = (current_time - current_time).seconds / 3600 if prev_time else 0
    if shift_duration > 14:
        print(f"{current_employee} ({current_position}) has worked for more than 14 hours in a single shift")

def analyze_timecard(df):
    """
    Analyze the timecard and print relevant information.

    Parameters:
    - df (pd.DataFrame): Timecard data.
    """
    # Initialize variables for tracking consecutive days
    prev_time = None
    
    # Iterate through rows to analyze the timecard
    for _, row in df.iterrows():
        current_employee = row['Employee Name']
        current_position = row['Position ID']  # Adjust column name based on your data
        current_time = row['Time']
        
        analyze_timecard_row(prev_time, current_time, current_employee, current_position)
        
        # Update previous time
        prev_time = current_time

# File path
filename = r"C:\Users\hp\OneDrive\Desktop\MCA BVICAM\Assignment_Timecard.xlsx"

# Load timecard data
timecard_data = load_timecard(filename)

# Analyze the timecard
analyze_timecard(timecard_data)
# Out:
# AGeX, WaMhaW REGerM PeWa (WFS000588) has worked for 7 consecutive days.
# AGeX, WaMhaW REGerM PeWa (WFS000588) has less than 10 hours between shifts but more than 1 hour.
# AGeX, WaMhaW REGerM PeWa (WFS000588) has less than 10 hours between shifts but more than 1 hour.
# AGeX, WaMhaW REGerM PeWa (WFS000588) has less than 10 hours between shifts but more than 1 hour.
# AGeX, WaMhaW REGerM PeWa (WFS000588) has less than 10 hours between shifts but more than 1 hour.
# AGeX, WaMhaW REGerM PeWa (WFS000588) has less than 10 hours between shifts but more than 1 hour.
# AXcEcer, ECar JesAs (WFS000541) has less than 10 hours between shifts but more than 1 hour.
# AXcEcer, ECar JesAs (WFS000541) has worked for 7 consecutive days.
# AXcEcer, ECar JesAs (WFS000541) has less than 10 hours between shifts but more than 1 hour.
# AXcEcer, ECar JesAs (WFS000541) has less than 10 hours between shifts but more than 1 hour.
# AXcEcer, ECar JesAs (WFS000541) has worked for 7 consecutive days.
# AXcEcer, ECar JesAs (WFS000541) has less than 10 hours between shifts but more than 1 hour.
# AXcEcer, ECar JesAs (WFS000541) has worked for 7 consecutive days.
# AXcEcer, ECar JesAs (WFS000541) has less than 10 hours between shifts but more than 1 hour.
# AXcEcer, ECar JesAs (WFS000541) has less than 10 hours between shifts but more than 1 hour.
# AXcEcer, ECar JesAs (WFS000541) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has worked for 7 consecutive days.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# AXvarez, Edgar (WFS000457) has less than 10 hours between shifts but more than 1 hour.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has less than 10 hours between shifts but more than 1 hour.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has less than 10 hours between shifts but more than 1 hour.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has worked for 7 consecutive days.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has less than 10 hours between shifts but more than 1 hour.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has less than 10 hours between shifts but more than 1 hour.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has less than 10 hours between shifts but more than 1 hour.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has less than 10 hours between shifts but more than 1 hour.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has less than 10 hours between shifts but more than 1 hour.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has less than 10 hours between shifts but more than 1 hour.
# ArCeWMa FXEres, JEWaMhaW (WFS000584) has less than 10 hours between shifts but more than 1 hour.
# ArEsMigAi, AXexaWder (WFS000306) has less than 10 hours between shifts but more than 1 hour.
# ArEsMigAi, AXexaWder (WFS000306) has less than 10 hours between shifts but more than 1 hour.
# ArEsMigAi, AXexaWder (WFS000306) has worked for 7 consecutive days.
# ArEsMigAi, AXexaWder (WFS000306) has less than 10 hours between shifts but more than 1 hour.
# ArEsMigAi, AXexaWder (WFS000306) has less than 10 hours between shifts but more than 1 hour.
# ArEsMigAi, AXexaWder (WFS000306) has less than 10 hours between shifts but more than 1 hour.
# ArEsMigAi, AXexaWder (WFS000306) has less than 10 hours between shifts but more than 1 hour.
# ArEsMigAi, AXexaWder (WFS000306) has less than 10 hours between shifts but more than 1 hour.
# ArevaXE, JEse (WFS000491) has less than 10 hours between shifts but more than 1 hour.
# ArevaXE, JEse (WFS000491) has less than 10 hours between shifts but more than 1 hour.
# ArevaXE, JEse (WFS000491) has less than 10 hours between shifts but more than 1 hour.
# ArevaXE, JEse (WFS000491) has worked for 7 consecutive days.
# ArevaXE, JEse (WFS000491) has less than 10 hours between shifts but more than 1 hour.
# ArevaXE, JEse (WFS000491) has less than 10 hours between shifts but more than 1 hour.
# ArevaXE, JEse (WFS000491) has less than 10 hours between shifts but more than 1 hour.
# ArevaXE, JEse (WFS000491) has worked for 7 consecutive days.
# ArevaXE, JEse (WFS000491) has worked for 7 consecutive days.
# ArevaXE, JEse (WFS000491) has less than 10 hours between shifts but more than 1 hour.
# ArevaXE, JEse (WFS000491) has less than 10 hours between shifts but more than 1 hour.
# ArevaXE, JEse (WFS000491) has less than 10 hours between shifts but more than 1 hour.
# Arias, FeXipe (WFS000170) has less than 10 hours between shifts but more than 1 hour.
# Arias, FeXipe (WFS000170) has less than 10 hours between shifts but more than 1 hour.
# Arias, FeXipe (WFS000170) has worked for 7 consecutive days.
# Arias, FeXipe (WFS000170) has less than 10 hours between shifts but more than 1 hour.
# Arias, FeXipe (WFS000170) has less than 10 hours between shifts but more than 1 hour.
# Arias, FeXipe (WFS000170) has less than 10 hours between shifts but more than 1 hour.
# Arias, FeXipe (WFS000170) has less than 10 hours between shifts but more than 1 hour.
# Arias, FeXipe (WFS000170) has less than 10 hours between shifts but more than 1 hour.
# Arias, FeXipe (WFS000170) has less than 10 hours between shifts but more than 1 hour.
# Arias, FeXipe (WFS000170) has less than 10 hours between shifts but more than 1 hour.
# ArrAMia, AXexis ArMArE (WFS000518) has less than 10 hours between shifts but more than 1 hour.
# ArrAMia, AXexis ArMArE (WFS000518) has less than 10 hours between shifts but more than 1 hour.
# ArrAMia, AXexis ArMArE (WFS000518) has worked for 7 consecutive days.
# ArrAMia, AXexis ArMArE (WFS000518) has less than 10 hours between shifts but more than 1 hour.
# ArrAMia, AXexis ArMArE (WFS000518) has less than 10 hours between shifts but more than 1 hour.
# ArrAMia, AXexis ArMArE (WFS000518) has less than 10 hours between shifts but more than 1 hour.
# CAevas ZavaXa, JErge XAis (WFS000571) has less than 10 hours between shifts but more than 1 hour.
# CAevas ZavaXa, JErge XAis (WFS000571) has worked for 7 consecutive days.
# CAevas ZavaXa, JErge XAis (WFS000571) has less than 10 hours between shifts but more than 1 hour.
# CAevas ZavaXa, JErge XAis (WFS000571) has less than 10 hours between shifts but more than 1 hour.
# CAevas ZavaXa, JErge XAis (WFS000571) has less than 10 hours between shifts but more than 1 hour.
# CAevas ZavaXa, JErge XAis (WFS000571) has less than 10 hours between shifts but more than 1 hour.
# CAevas ZavaXa, JErge XAis (WFS000571) has less than 10 hours between shifts but more than 1 hour.
# CAevas ZavaXa, JErge XAis (WFS000571) has less than 10 hours between shifts but more than 1 hour.
# CAevas ZavaXa, JErge XAis (WFS000571) has worked for 7 consecutive days.
# CAevas ZavaXa, JErge XAis (WFS000571) has less than 10 hours between shifts but more than 1 hour.
# CAevas ZavaXa, JErge XAis (WFS000571) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has worked for 7 consecutive days.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has worked for 7 consecutive days.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CEMMa, Jessica (WFS000503) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CErMes, DEAgXas Farid (WFS000495) has worked for 7 consecutive days.
# CErMes, DEAgXas Farid (WFS000495) has less than 10 hours between shifts but more than 1 hour.
# CEreira Jr, JEse (WFS000456) has less than 10 hours between shifts but more than 1 hour.
# CEreira Jr, JEse (WFS000456) has less than 10 hours between shifts but more than 1 hour.
# CEreira Jr, JEse (WFS000456) has less than 10 hours between shifts but more than 1 hour.
# CEreira Jr, JEse (WFS000456) has worked for 7 consecutive days.
# CEreira Jr, JEse (WFS000456) has less than 10 hours between shifts but more than 1 hour.
# CEreira Jr, JEse (WFS000456) has less than 10 hours between shifts but more than 1 hour.
# CEreira Jr, JEse (WFS000456) has less than 10 hours between shifts but more than 1 hour.
# CEreira Jr, JEse (WFS000456) has worked for 7 consecutive days.
# CEreira Jr, JEse (WFS000456) has worked for 7 consecutive days.
# CEreira Jr, JEse (WFS000456) has less than 10 hours between shifts but more than 1 hour.
# CEreira Jr, JEse (WFS000456) has less than 10 hours between shifts but more than 1 hour.
# CEreira Jr, JEse (WFS000456) has less than 10 hours between shifts but more than 1 hour.
# CaMXEck, CEhaCCed (WFS000362) has less than 10 hours between shifts but more than 1 hour.
# CaMXEck, CEhaCCed (WFS000362) has less than 10 hours between shifts but more than 1 hour.
# CaMXEck, CEhaCCed (WFS000362) has less than 10 hours between shifts but more than 1 hour.
# CaMXEck, CEhaCCed (WFS000362) has less than 10 hours between shifts but more than 1 hour.
# CaMXEck, CEhaCCed (WFS000362) has less than 10 hours between shifts but more than 1 hour.
# CaMXEck, CEhaCCed (WFS000362) has less than 10 hours between shifts but more than 1 hour.
# CaMXEck, CEhaCCed (WFS000362) has less than 10 hours between shifts but more than 1 hour.
# CaMXEck, CEhaCCed (WFS000362) has less than 10 hours between shifts but more than 1 hour.
# CaMXEck, CEhaCCed (WFS000362) has less than 10 hours between shifts but more than 1 hour.
# CaMaXaWE, CeghaW (WFS000153) has less than 10 hours between shifts but more than 1 hour.
# CaMaXaWE, CeghaW (WFS000153) has less than 10 hours between shifts but more than 1 hour.
# CaMaXaWE, CeghaW (WFS000153) has less than 10 hours between shifts but more than 1 hour.
# CaMaXaWE, CeghaW (WFS000153) has less than 10 hours between shifts but more than 1 hour.
# CaMaXaWE, CeghaW (WFS000153) has less than 10 hours between shifts but more than 1 hour.
# CaMaXaWE, CeghaW (WFS000153) has less than 10 hours between shifts but more than 1 hour.
# CaMaXaWE, CeghaW (WFS000153) has less than 10 hours between shifts but more than 1 hour.
# CaMaXaWE, CeghaW (WFS000153) has less than 10 hours between shifts but more than 1 hour.
# CaMaXaWE, CeghaW (WFS000153) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has worked for 7 consecutive days.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has worked for 7 consecutive days.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has worked for 7 consecutive days.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CaXdEWadE, AXfEWsE (WFS000463) has less than 10 hours between shifts but more than 1 hour.
# CarMer, XyWWeXX DejAaW Jr (WFS000576) has less than 10 hours between shifts but more than 1 hour.
# CaraGiXXa, AWMhEWy (WFS000514) has less than 10 hours between shifts but more than 1 hour.
# CaraGiXXa, AWMhEWy (WFS000514) has less than 10 hours between shifts but more than 1 hour.
# CaraGiXXa, AWMhEWy (WFS000514) has worked for 7 consecutive days.
# CaraGiXXa, AWMhEWy (WFS000514) has less than 10 hours between shifts but more than 1 hour.
# Caxies, MerreXX (WFS000500) has less than 10 hours between shifts but more than 1 hour.
# Caxies, MerreXX (WFS000500) has less than 10 hours between shifts but more than 1 hour.
# Caxies, MerreXX (WFS000500) has worked for 7 consecutive days.
# Caxies, MerreXX (WFS000500) has less than 10 hours between shifts but more than 1 hour.
# Caxies, MerreXX (WFS000500) has less than 10 hours between shifts but more than 1 hour.
# Caxies, MerreXX (WFS000500) has less than 10 hours between shifts but more than 1 hour.
# Caxies, MerreXX (WFS000500) has less than 10 hours between shifts but more than 1 hour.
# Caxies, MerreXX (WFS000500) has less than 10 hours between shifts but more than 1 hour.
# Caxies, MerreXX (WFS000500) has less than 10 hours between shifts but more than 1 hour.
# Caxies, MerreXX (WFS000500) has worked for 7 consecutive days.
# Caxies, MerreXX (WFS000500) has worked for 7 consecutive days.
# Caxies, MerreXX (WFS000500) has less than 10 hours between shifts but more than 1 hour.
# CcRAWWeX, REWaXd Xee (WFS000501) has less than 10 hours between shifts but more than 1 hour.
# CcRAWWeX, REWaXd Xee (WFS000501) has less than 10 hours between shifts but more than 1 hour.
# CcRAWWeX, REWaXd Xee (WFS000501) has less than 10 hours between shifts but more than 1 hour.
# CcRAWWeX, REWaXd Xee (WFS000501) has less than 10 hours between shifts but more than 1 hour.
# CcRAWWeX, REWaXd Xee (WFS000501) has less than 10 hours between shifts but more than 1 hour.
# CcRAWWeX, REWaXd Xee (WFS000501) has less than 10 hours between shifts but more than 1 hour.
# CcRAWWeX, REWaXd Xee (WFS000501) has less than 10 hours between shifts but more than 1 hour.
# CcRAWWeX, REWaXd Xee (WFS000501) has less than 10 hours between shifts but more than 1 hour.
# CeWdEza, Erik (WFS000465) has less than 10 hours between shifts but more than 1 hour.
# CeWdEza, Erik (WFS000465) has less than 10 hours between shifts but more than 1 hour.
# CeWdEza, Erik (WFS000465) has less than 10 hours between shifts but more than 1 hour.
# CeWdEza, Erik (WFS000465) has less than 10 hours between shifts but more than 1 hour.
# CeciWa, SiXvesMre Jr (WFS000528) has less than 10 hours between shifts but more than 1 hour.
# CeciWa, SiXvesMre Jr (WFS000528) has less than 10 hours between shifts but more than 1 hour.
# CeciWa, SiXvesMre Jr (WFS000528) has less than 10 hours between shifts but more than 1 hour.
# CeciWa, SiXvesMre Jr (WFS000528) has worked for 7 consecutive days.
# CeciWa, SiXvesMre Jr (WFS000528) has less than 10 hours between shifts but more than 1 hour.
# CeciWa, SiXvesMre Jr (WFS000528) has less than 10 hours between shifts but more than 1 hour.
# CeciWa, SiXvesMre Jr (WFS000528) has worked for 7 consecutive days.
# CercadE, CrisMiaW (WFS000496) has less than 10 hours between shifts but more than 1 hour.
# CercadE, CrisMiaW (WFS000496) has less than 10 hours between shifts but more than 1 hour.
# CercadE, CrisMiaW (WFS000496) has less than 10 hours between shifts but more than 1 hour.
# CercadE, CrisMiaW (WFS000496) has less than 10 hours between shifts but more than 1 hour.
# CercadE, CrisMiaW (WFS000496) has worked for 7 consecutive days.
# CercadE, CrisMiaW (WFS000496) has less than 10 hours between shifts but more than 1 hour.
# CercadE, CrisMiaW (WFS000496) has less than 10 hours between shifts but more than 1 hour.
# CercadE, CrisMiaW (WFS000496) has less than 10 hours between shifts but more than 1 hour.
# CercadE, CrisMiaW (WFS000496) has less than 10 hours between shifts but more than 1 hour.
# CercadE, SaAX (WFS000446) has less than 10 hours between shifts but more than 1 hour.
# CercadE, SaAX (WFS000446) has less than 10 hours between shifts but more than 1 hour.
# CercadE, SaAX (WFS000446) has less than 10 hours between shifts but more than 1 hour.
# CercadE, SaAX (WFS000446) has worked for 7 consecutive days.
# CercadE, SaAX (WFS000446) has less than 10 hours between shifts but more than 1 hour.
# CercadE, SaAX (WFS000446) has less than 10 hours between shifts but more than 1 hour.
# CercadE, SaAX (WFS000446) has worked for 7 consecutive days.
# CercadE, SaAX (WFS000446) has less than 10 hours between shifts but more than 1 hour.
# CercadE, SaAX (WFS000446) has less than 10 hours between shifts but more than 1 hour.
# CercadE, SaAX (WFS000446) has less than 10 hours between shifts but more than 1 hour.
# CercadE, SaAX (WFS000446) has worked for 7 consecutive days.
# CercadE, SaAX (WFS000446) has less than 10 hours between shifts but more than 1 hour.
# CesiWa CEreWE, KeviW FaGiaW (WFS000548) has worked for 7 consecutive days.
# CesiWa CEreWE, KeviW FaGiaW (WFS000548) has less than 10 hours between shifts but more than 1 hour.
# CesiWa CEreWE, KeviW FaGiaW (WFS000548) has less than 10 hours between shifts but more than 1 hour.
# CesiWa CEreWE, KeviW FaGiaW (WFS000548) has less than 10 hours between shifts but more than 1 hour.
# CesiWa CEreWE, KeviW FaGiaW (WFS000548) has less than 10 hours between shifts but more than 1 hour.
# CesiWa CEreWE, KeviW FaGiaW (WFS000548) has less than 10 hours between shifts but more than 1 hour.
# CesiWa CEreWE, KeviW FaGiaW (WFS000548) has less than 10 hours between shifts but more than 1 hour.
# CesiWa CEreWE, KeviW FaGiaW (WFS000548) has less than 10 hours between shifts but more than 1 hour.
# ChaCErE, HEXger CarMiWez (WFS000509) has less than 10 hours between shifts but more than 1 hour.
# ChaCErE, HEXger CarMiWez (WFS000509) has worked for 7 consecutive days.
# ChaCErE, HEXger CarMiWez (WFS000509) has less than 10 hours between shifts but more than 1 hour.
# ChaCErE, HEXger CarMiWez (WFS000509) has less than 10 hours between shifts but more than 1 hour.
# ChaCErE, HEXger CarMiWez (WFS000509) has less than 10 hours between shifts but more than 1 hour.
# ChaCErE, HEXger CarMiWez (WFS000509) has less than 10 hours between shifts but more than 1 hour.
# ChaCErE, HEXger CarMiWez (WFS000509) has less than 10 hours between shifts but more than 1 hour.
# ChaCErE, HEXger CarMiWez (WFS000509) has worked for 7 consecutive days.
# ChaCErE, HEXger CarMiWez (WFS000509) has less than 10 hours between shifts but more than 1 hour.
# ChaCErE, HEXger CarMiWez (WFS000509) has worked for 7 consecutive days.
# ChaCErE, HEXger CarMiWez (WFS000509) has less than 10 hours between shifts but more than 1 hour.
# ChaCErE, HEXger CarMiWez (WFS000509) has less than 10 hours between shifts but more than 1 hour.
# CharXes, EGadiah SEraccE Jr (WFS000566) has less than 10 hours between shifts but more than 1 hour.
# CharXes, EGadiah SEraccE Jr (WFS000566) has less than 10 hours between shifts but more than 1 hour.
# CharXes, EGadiah SEraccE Jr (WFS000566) has less than 10 hours between shifts but more than 1 hour.
# CiGriaW DeXgadE, EXeWa S (WFS000574) has less than 10 hours between shifts but more than 1 hour.
# CiGriaW DeXgadE, EXeWa S (WFS000574) has less than 10 hours between shifts but more than 1 hour.
# CiGriaW DeXgadE, EXeWa S (WFS000574) has worked for 7 consecutive days.
# CiGriaW DeXgadE, EXeWa S (WFS000574) has less than 10 hours between shifts but more than 1 hour.
# CiGriaW DeXgadE, EXeWa S (WFS000574) has worked for 7 consecutive days.
# CiGriaW DeXgadE, EXeWa S (WFS000574) has less than 10 hours between shifts but more than 1 hour.
# CiGriaW DeXgadE, EXeWa S (WFS000574) has less than 10 hours between shifts but more than 1 hour.
# DECiWgAez AviWa, CigAeX AWgeX (WFS000569) has less than 10 hours between shifts but more than 1 hour.
# DECiWgAez AviWa, CigAeX AWgeX (WFS000569) has worked for 7 consecutive days.
# DECiWgAez AviWa, CigAeX AWgeX (WFS000569) has less than 10 hours between shifts but more than 1 hour.
# DECiWgAez AviWa, CigAeX AWgeX (WFS000569) has less than 10 hours between shifts but more than 1 hour.
# DECiWgAez AviWa, CigAeX AWgeX (WFS000569) has less than 10 hours between shifts but more than 1 hour.
# DECiWgAez AviWa, CigAeX AWgeX (WFS000569) has worked for 7 consecutive days.
# DECiWgAez AviWa, CigAeX AWgeX (WFS000569) has less than 10 hours between shifts but more than 1 hour.
# DECiWgAez AviWa, CigAeX AWgeX (WFS000569) has less than 10 hours between shifts but more than 1 hour.
# DECiWgAez AviWa, CigAeX AWgeX (WFS000569) has less than 10 hours between shifts but more than 1 hour.
# De XEs SaWMEs, JEseph XAis (WFS000582) has less than 10 hours between shifts but more than 1 hour.
# De XEs SaWMEs, JEseph XAis (WFS000582) has less than 10 hours between shifts but more than 1 hour.
# De XEs SaWMEs, JEseph XAis (WFS000582) has worked for 7 consecutive days.
# De XEs SaWMEs, JEseph XAis (WFS000582) has less than 10 hours between shifts but more than 1 hour.
# De XEs SaWMEs, JEseph XAis (WFS000582) has less than 10 hours between shifts but more than 1 hour.
# De XEs SaWMEs, JEseph XAis (WFS000582) has worked for 7 consecutive days.
# De XEs SaWMEs, JEseph XAis (WFS000582) has less than 10 hours between shifts but more than 1 hour.
# De XEs SaWMEs, JEseph XAis (WFS000582) has worked for 7 consecutive days.
# De XEs SaWMEs, JEseph XAis (WFS000582) has less than 10 hours between shifts but more than 1 hour.
# De Xa Cerda, IgWaciE (WFS000318) has less than 10 hours between shifts but more than 1 hour.
# De Xa Cerda, IgWaciE (WFS000318) has less than 10 hours between shifts but more than 1 hour.
# De Xa Cerda, IgWaciE (WFS000318) has less than 10 hours between shifts but more than 1 hour.
# De Xa Cerda, IgWaciE (WFS000318) has less than 10 hours between shifts but more than 1 hour.
# De Xa Cerda, IgWaciE (WFS000318) has less than 10 hours between shifts but more than 1 hour.
# De Xa Cerda, IgWaciE (WFS000318) has less than 10 hours between shifts but more than 1 hour.
# De Xa Cerda, IgWaciE (WFS000318) has less than 10 hours between shifts but more than 1 hour.
# De Xa Cerda, IgWaciE (WFS000318) has less than 10 hours between shifts but more than 1 hour.
# De Xa Cerda, IgWaciE (WFS000318) has less than 10 hours between shifts but more than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has less than 10 hours between shifts but more than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has less than 10 hours between shifts but more than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has less than 10 hours between shifts but more than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has less than 10 hours between shifts but more than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has less than 10 hours between shifts but more than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has worked for 7 consecutive days.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has less than 10 hours between shifts but more than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has less than 10 hours between shifts but more than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has less than 10 hours between shifts but more than 1 hour.
# DeXgadiXXE REdarMe, ChrisMiaW S (WFS000523) has less than 10 hours between shifts but more than 1 hour.
# DiWh, DaA (WFS000268) has less than 10 hours between shifts but more than 1 hour.
# DiWh, DaA (WFS000268) has less than 10 hours between shifts but more than 1 hour.
# DiWh, DaA (WFS000268) has worked for 7 consecutive days.
# DiWh, DaA (WFS000268) has less than 10 hours between shifts but more than 1 hour.
# DiWh, DaA (WFS000268) has less than 10 hours between shifts but more than 1 hour.
# DiWh, DaA (WFS000268) has less than 10 hours between shifts but more than 1 hour.
# DiWh, DaA (WFS000268) has worked for 7 consecutive days.
# DiWh, DaA (WFS000268) has less than 10 hours between shifts but more than 1 hour.
# DiWh, DaA (WFS000268) has less than 10 hours between shifts but more than 1 hour.
# DiWh, DaA (WFS000268) has worked for 7 consecutive days.
# DiWh, DaA (WFS000268) has less than 10 hours between shifts but more than 1 hour.
# DiWh, DaA (WFS000268) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# DiXXard, JEwaWW Cedric (WFS000519) has less than 10 hours between shifts but more than 1 hour.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has less than 10 hours between shifts but more than 1 hour.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has worked for 7 consecutive days.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has less than 10 hours between shifts but more than 1 hour.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has less than 10 hours between shifts but more than 1 hour.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has worked for 7 consecutive days.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has less than 10 hours between shifts but more than 1 hour.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has less than 10 hours between shifts but more than 1 hour.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has less than 10 hours between shifts but more than 1 hour.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has less than 10 hours between shifts but more than 1 hour.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has worked for 7 consecutive days.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has less than 10 hours between shifts but more than 1 hour.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has worked for 7 consecutive days.
# Diaz GaXvez, RicardE JEsAe (WFS000551) has less than 10 hours between shifts but more than 1 hour.
# EXivares, FeXCaW (WFS000508) has less than 10 hours between shifts but more than 1 hour.
# EXivares, FeXCaW (WFS000508) has worked for 7 consecutive days.
# EXivares, FeXCaW (WFS000508) has less than 10 hours between shifts but more than 1 hour.
# EXivares, FeXCaW (WFS000508) has worked for 7 consecutive days.
# EXivares, FeXCaW (WFS000508) has less than 10 hours between shifts but more than 1 hour.
# EXivares, FeXCaW (WFS000508) has less than 10 hours between shifts but more than 1 hour.
# EXivares, FeXCaW (WFS000508) has worked for 7 consecutive days.
# EXivares, FeXCaW (WFS000508) has less than 10 hours between shifts but more than 1 hour.
# EXivares, FeXCaW (WFS000508) has less than 10 hours between shifts but more than 1 hour.
# EXivares, FeXCaW (WFS000508) has less than 10 hours between shifts but more than 1 hour.
# EXivares, FeXCaW (WFS000508) has less than 10 hours between shifts but more than 1 hour.
# EXivares, FeXCaW (WFS000508) has less than 10 hours between shifts but more than 1 hour.
# EasMCaW, CichaeX (WFS000414) has less than 10 hours between shifts but more than 1 hour.
# EasMCaW, CichaeX (WFS000414) has less than 10 hours between shifts but more than 1 hour.
# EasMCaW, CichaeX (WFS000414) has less than 10 hours between shifts but more than 1 hour.
# EasMCaW, CichaeX (WFS000414) has less than 10 hours between shifts but more than 1 hour.
# EasMCaW, CichaeX (WFS000414) has less than 10 hours between shifts but more than 1 hour.
# EasMCaW, CichaeX (WFS000414) has less than 10 hours between shifts but more than 1 hour.
# EasMCaW, CichaeX (WFS000414) has less than 10 hours between shifts but more than 1 hour.
# EasMCaW, CichaeX (WFS000414) has less than 10 hours between shifts but more than 1 hour.
# EasMCaW, CichaeX (WFS000414) has less than 10 hours between shifts but more than 1 hour.
# ErEpeza, JEvaW (WFS000382) has worked for 7 consecutive days.
# ErEpeza, JEvaW (WFS000382) has less than 10 hours between shifts but more than 1 hour.
# ErEpeza, JEvaW (WFS000382) has less than 10 hours between shifts but more than 1 hour.
# ErEpeza, JEvaW (WFS000382) has less than 10 hours between shifts but more than 1 hour.
# ErEpeza, JEvaW (WFS000382) has less than 10 hours between shifts but more than 1 hour.
# ErEpeza, JEvaW (WFS000382) has less than 10 hours between shifts but more than 1 hour.
# ErEpeza, JEvaW (WFS000382) has less than 10 hours between shifts but more than 1 hour.
# ErEpeza, JEvaW (WFS000382) has less than 10 hours between shifts but more than 1 hour.
# ErEzcE, SaAX (WFS000442) has less than 10 hours between shifts but more than 1 hour.
# ErEzcE, SaAX (WFS000442) has less than 10 hours between shifts but more than 1 hour.
# ErEzcE, SaAX (WFS000442) has less than 10 hours between shifts but more than 1 hour.
# ErEzcE, SaAX (WFS000442) has worked for 7 consecutive days.
# ErEzcE, SaAX (WFS000442) has less than 10 hours between shifts but more than 1 hour.
# ErEzcE, SaAX (WFS000442) has less than 10 hours between shifts but more than 1 hour.
# ErEzcE, SaAX (WFS000442) has less than 10 hours between shifts but more than 1 hour.
# ErEzcE, SaAX (WFS000442) has worked for 7 consecutive days.
# ErEzcE, SaAX (WFS000442) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# ErMiz, AGigaiX (WFS000372) has less than 10 hours between shifts but more than 1 hour.
# EsMrada, JEse FeXix (WFS000552) has less than 10 hours between shifts but more than 1 hour.
# EsMrada, JEse FeXix (WFS000552) has less than 10 hours between shifts but more than 1 hour.
# EsMrada, JEse FeXix (WFS000552) has less than 10 hours between shifts but more than 1 hour.
# EsMrada, JEse FeXix (WFS000552) has less than 10 hours between shifts but more than 1 hour.
# EsMrada, JEse FeXix (WFS000552) has less than 10 hours between shifts but more than 1 hour.
# EsMrada, JEse FeXix (WFS000552) has worked for 7 consecutive days.
# EsMrada, JEse FeXix (WFS000552) has less than 10 hours between shifts but more than 1 hour.
# EsMrada, JEse FeXix (WFS000552) has less than 10 hours between shifts but more than 1 hour.
# EsMrada, JEse FeXix (WFS000552) has worked for 7 consecutive days.
# EsMrada, JEse FeXix (WFS000552) has less than 10 hours between shifts but more than 1 hour.
# EsMrada, JEse FeXix (WFS000552) has less than 10 hours between shifts but more than 1 hour.
# FaGiaW CiraWda, JEse (WFS000530) has less than 10 hours between shifts but more than 1 hour.
# FaGiaW CiraWda, JEse (WFS000530) has worked for 7 consecutive days.
# FaGiaW CiraWda, JEse (WFS000530) has less than 10 hours between shifts but more than 1 hour.
# FaGiaW CiraWda, JEse (WFS000530) has worked for 7 consecutive days.
# FaGiaW CiraWda, JEse (WFS000530) has less than 10 hours between shifts but more than 1 hour.
# FaGiaW CiraWda, JEse (WFS000530) has less than 10 hours between shifts but more than 1 hour.
# FaGiaW CiraWda, JEse (WFS000530) has less than 10 hours between shifts but more than 1 hour.
# FaGiaW CiraWda, JEse (WFS000530) has worked for 7 consecutive days.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# FeXix, XeEWeX (WFS000183) has worked for 7 consecutive days.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# FeXix, XeEWeX (WFS000183) has less than 10 hours between shifts but more than 1 hour.
# GAMierrez, PedrE CigAeX (WFS000579) has less than 10 hours between shifts but more than 1 hour.
# GAMierrez, PedrE CigAeX (WFS000579) has worked for 7 consecutive days.
# GAMierrez, PedrE CigAeX (WFS000579) has less than 10 hours between shifts but more than 1 hour.
# GAMierrez, PedrE CigAeX (WFS000579) has less than 10 hours between shifts but more than 1 hour.
# GAMierrez, PedrE CigAeX (WFS000579) has less than 10 hours between shifts but more than 1 hour.
# GAMierrez, PedrE CigAeX (WFS000579) has less than 10 hours between shifts but more than 1 hour.
# GAMierrez, PedrE CigAeX (WFS000579) has worked for 7 consecutive days.
# GAMierrez, PedrE CigAeX (WFS000579) has less than 10 hours between shifts but more than 1 hour.
# GAMierrez, PedrE CigAeX (WFS000579) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GAeWdia, JAaW CarXEs (WFS000473) has worked for 7 consecutive days.
# GAeWdia, JAaW CarXEs (WFS000473) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaWks, GryaW (WFS000226) has less than 10 hours between shifts but more than 1 hour.
# GaXCes, EXias XEpez (WFS000127) has less than 10 hours between shifts but more than 1 hour.
# GaXCes, EXias XEpez (WFS000127) has less than 10 hours between shifts but more than 1 hour.
# GaXCes, EXias XEpez (WFS000127) has less than 10 hours between shifts but more than 1 hour.
# GaXCes, EXias XEpez (WFS000127) has less than 10 hours between shifts but more than 1 hour.
# GaXCes, EXias XEpez (WFS000127) has less than 10 hours between shifts but more than 1 hour.
# GaXCes, EXias XEpez (WFS000127) has less than 10 hours between shifts but more than 1 hour.
# GaXCes, EXias XEpez (WFS000127) has less than 10 hours between shifts but more than 1 hour.
# GarWes, JAsMiW (WFS000181) has less than 10 hours between shifts but more than 1 hour.
# GarWes, JAsMiW (WFS000181) has less than 10 hours between shifts but more than 1 hour.
# GarWes, JAsMiW (WFS000181) has worked for 7 consecutive days.
# GarWes, JAsMiW (WFS000181) has less than 10 hours between shifts but more than 1 hour.
# GarWes, JAsMiW (WFS000181) has less than 10 hours between shifts but more than 1 hour.
# GarWes, JAsMiW (WFS000181) has less than 10 hours between shifts but more than 1 hour.
# GarWes, JAsMiW (WFS000181) has less than 10 hours between shifts but more than 1 hour.
# GarWes, JAsMiW (WFS000181) has less than 10 hours between shifts but more than 1 hour.
# GarWes, JAsMiW (WFS000181) has less than 10 hours between shifts but more than 1 hour.
# GarWes, JAsMiW (WFS000181) has less than 10 hours between shifts but more than 1 hour.
# GrACfieXd, CErWeXiAs (WFS000515) has less than 10 hours between shifts but more than 1 hour.
# GrACfieXd, CErWeXiAs (WFS000515) has less than 10 hours between shifts but more than 1 hour.
# GrACfieXd, CErWeXiAs (WFS000515) has less than 10 hours between shifts but more than 1 hour.
# GrACfieXd, CErWeXiAs (WFS000515) has worked for 7 consecutive days.
# GrACfieXd, CErWeXiAs (WFS000515) has less than 10 hours between shifts but more than 1 hour.
# GrACfieXd, CErWeXiAs (WFS000515) has less than 10 hours between shifts but more than 1 hour.
# GrACfieXd, CErWeXiAs (WFS000515) has less than 10 hours between shifts but more than 1 hour.
# GrACfieXd, CErWeXiAs (WFS000515) has less than 10 hours between shifts but more than 1 hour.
# GrACfieXd, CErWeXiAs (WFS000515) has worked for 7 consecutive days.
# GrACfieXd, CErWeXiAs (WFS000515) has less than 10 hours between shifts but more than 1 hour.
# HAWMer, ViWceWM De PaAX (WFS000538) has less than 10 hours between shifts but more than 1 hour.
# HAWMer, ViWceWM De PaAX (WFS000538) has less than 10 hours between shifts but more than 1 hour.
# HAWMer, ViWceWM De PaAX (WFS000538) has less than 10 hours between shifts but more than 1 hour.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has less than 10 hours between shifts but more than 1 hour.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has less than 10 hours between shifts but more than 1 hour.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has less than 10 hours between shifts but more than 1 hour.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has worked for 7 consecutive days.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has less than 10 hours between shifts but more than 1 hour.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has less than 10 hours between shifts but more than 1 hour.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has less than 10 hours between shifts but more than 1 hour.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has less than 10 hours between shifts but more than 1 hour.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has worked for 7 consecutive days.
# HEGGie ErMega, SeGasMiaW CichaeX (WFS000549) has less than 10 hours between shifts but more than 1 hour.
# HaCiXMEW, DeaWMe DevEW (WFS000536) has less than 10 hours between shifts but more than 1 hour.
# HaCiXMEW, DeaWMe DevEW (WFS000536) has less than 10 hours between shifts but more than 1 hour.
# HaCiXMEW, DeaWMe DevEW (WFS000536) has less than 10 hours between shifts but more than 1 hour.
# HaCiXMEW, DeaWMe DevEW (WFS000536) has less than 10 hours between shifts but more than 1 hour.
# HaCiXMEW, DeaWMe DevEW (WFS000536) has less than 10 hours between shifts but more than 1 hour.
# HaCiXMEW, DeaWMe DevEW (WFS000536) has less than 10 hours between shifts but more than 1 hour.
# HerCEsiXXE, PedrE (WFS000185) has less than 10 hours between shifts but more than 1 hour.
# HerCEsiXXE, PedrE (WFS000185) has less than 10 hours between shifts but more than 1 hour.
# HerCEsiXXE, PedrE (WFS000185) has less than 10 hours between shifts but more than 1 hour.
# HerCEsiXXE, PedrE (WFS000185) has less than 10 hours between shifts but more than 1 hour.
# HerCEsiXXE, PedrE (WFS000185) has less than 10 hours between shifts but more than 1 hour.
# HerCEsiXXE, PedrE (WFS000185) has less than 10 hours between shifts but more than 1 hour.
# HerCEsiXXE, PedrE (WFS000185) has less than 10 hours between shifts but more than 1 hour.
# HerCEsiXXE, PedrE (WFS000185) has less than 10 hours between shifts but more than 1 hour.
# HerCEsiXXE, PedrE (WFS000185) has less than 10 hours between shifts but more than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has less than 10 hours between shifts but more than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has worked for 7 consecutive days.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has less than 10 hours between shifts but more than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has worked for 7 consecutive days.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has less than 10 hours between shifts but more than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has less than 10 hours between shifts but more than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has less than 10 hours between shifts but more than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has less than 10 hours between shifts but more than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has worked for 7 consecutive days.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has less than 10 hours between shifts but more than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has less than 10 hours between shifts but more than 1 hour.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has worked for 7 consecutive days.
# HerWaWdez SaWchez, AWdrew AWMhEWy (WFS000581) has less than 10 hours between shifts but more than 1 hour.
# IWGEAa, JeffersEW (WFS000546) has less than 10 hours between shifts but more than 1 hour.
# IWGEAa, JeffersEW (WFS000546) has less than 10 hours between shifts but more than 1 hour.
# IWGEAa, JeffersEW (WFS000546) has less than 10 hours between shifts but more than 1 hour.
# IWGEAa, JeffersEW (WFS000546) has less than 10 hours between shifts but more than 1 hour.
# IWGEAa, JeffersEW (WFS000546) has less than 10 hours between shifts but more than 1 hour.
# IWGEAa, JeffersEW (WFS000546) has less than 10 hours between shifts but more than 1 hour.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has less than 10 hours between shifts but more than 1 hour.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has less than 10 hours between shifts but more than 1 hour.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has worked for 7 consecutive days.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has less than 10 hours between shifts but more than 1 hour.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has less than 10 hours between shifts but more than 1 hour.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has less than 10 hours between shifts but more than 1 hour.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has worked for 7 consecutive days.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has less than 10 hours between shifts but more than 1 hour.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has less than 10 hours between shifts but more than 1 hour.
# JerEWiCE CEraXes, CarXEs D (WFS000557) has less than 10 hours between shifts but more than 1 hour.
# MAake, CasiaWE (WFS000228) has less than 10 hours between shifts but more than 1 hour.
# MAake, CasiaWE (WFS000228) has less than 10 hours between shifts but more than 1 hour.
# MAake, CasiaWE (WFS000228) has worked for 7 consecutive days.
# MAake, CasiaWE (WFS000228) has less than 10 hours between shifts but more than 1 hour.
# MAake, CasiaWE (WFS000228) has worked for 7 consecutive days.
# MAake, CasiaWE (WFS000228) has worked for 7 consecutive days.
# MAake, CasiaWE (WFS000228) has less than 10 hours between shifts but more than 1 hour.
# MAake, CasiaWE (WFS000228) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MAcker, CichaeX (WFS000360) has worked for 7 consecutive days.
# MAcker, CichaeX (WFS000360) has less than 10 hours between shifts but more than 1 hour.
# MaXeGi, ACirCasEAd (WFS000364) has less than 10 hours between shifts but more than 1 hour.
# MaXeGi, ACirCasEAd (WFS000364) has less than 10 hours between shifts but more than 1 hour.
# MaXeGi, ACirCasEAd (WFS000364) has less than 10 hours between shifts but more than 1 hour.
# MaXeGi, ACirCasEAd (WFS000364) has worked for 7 consecutive days.
# MaXeGi, ACirCasEAd (WFS000364) has worked for 7 consecutive days.
# MaXeGi, ACirCasEAd (WFS000364) has less than 10 hours between shifts but more than 1 hour.
# MaXeGi, ACirCasEAd (WFS000364) has less than 10 hours between shifts but more than 1 hour.
# MaXeGi, ACirCasEAd (WFS000364) has less than 10 hours between shifts but more than 1 hour.
# Merrazas, GriaW (WFS000180) has less than 10 hours between shifts but more than 1 hour.
# Merrazas, GriaW (WFS000180) has less than 10 hours between shifts but more than 1 hour.
# Merrazas, GriaW (WFS000180) has less than 10 hours between shifts but more than 1 hour.
# Merrazas, GriaW (WFS000180) has less than 10 hours between shifts but more than 1 hour.
# Merrazas, GriaW (WFS000180) has less than 10 hours between shifts but more than 1 hour.
# Merrazas, GriaW (WFS000180) has less than 10 hours between shifts but more than 1 hour.
# MraW, WiXXiaC Ha (WFS000345) has less than 10 hours between shifts but more than 1 hour.
# MraW, WiXXiaC Ha (WFS000345) has less than 10 hours between shifts but more than 1 hour.
# MraW, WiXXiaC Ha (WFS000345) has less than 10 hours between shifts but more than 1 hour.
# MraW, WiXXiaC Ha (WFS000345) has less than 10 hours between shifts but more than 1 hour.
# MraW, WiXXiaC Ha (WFS000345) has less than 10 hours between shifts but more than 1 hour.
# ...
# SaWchez PaCpXEWa, CrisMiaW AXGerM (WFS000521) has less than 10 hours between shifts but more than 1 hour.
# SaWchez PaCpXEWa, CrisMiaW AXGerM (WFS000521) has less than 10 hours between shifts but more than 1 hour.
# SaWchez PaCpXEWa, CrisMiaW AXGerM (WFS000521) has less than 10 hours between shifts but more than 1 hour.
# SaWchez, ArWAXfE (WFS000577) has less than 10 hours between shifts but more than 1 hour.
# SaWchez, ArWAXfE (WFS000577) has less than 10 hours between shifts but more than 1 hour.
# SaWchez, ArWAXfE (WFS000577) has less than 10 hours between shifts but more than 1 hour.
# SaWchez, ArWAXfE (WFS000577) has less than 10 hours between shifts but more than 1 hour.
# SaWchez, ArWAXfE (WFS000577) has less than 10 hours between shifts but more than 1 hour.
# SaWchez, ArWAXfE (WFS000577) has less than 10 hours between shifts but more than 1 hour.
# SavaWg, JEhW (WFS000393) has less than 10 hours between shifts but more than 1 hour.
# SavaWg, JEhW (WFS000393) has less than 10 hours between shifts but more than 1 hour.
# SavaWg, JEhW (WFS000393) has less than 10 hours between shifts but more than 1 hour.
# SavaWg, JEhW (WFS000393) has worked for 7 consecutive days.
# SavaWg, JEhW (WFS000393) has less than 10 hours between shifts but more than 1 hour.
# SavaWg, JEhW (WFS000393) has less than 10 hours between shifts but more than 1 hour.
# SavaWg, JEhW (WFS000393) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has worked for 7 consecutive days.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgXeMEW, REger (WFS000426) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, CaWpreeM (WFS000418) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, CaWpreeM (WFS000418) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, CaWpreeM (WFS000418) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, CaWpreeM (WFS000418) has worked for 7 consecutive days.
# SiWgh, CaWpreeM (WFS000418) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has worked for 7 consecutive days.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has worked for 7 consecutive days.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, JaspreeM (WFS000424) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# SiWgh, MarAWpreeM (WFS000246) has less than 10 hours between shifts but more than 1 hour.
# Sparks, KeWWeMh (WFS000101) has less than 10 hours between shifts but more than 1 hour.
# Sparks, KeWWeMh (WFS000101) has less than 10 hours between shifts but more than 1 hour.
# Sparks, KeWWeMh (WFS000101) has less than 10 hours between shifts but more than 1 hour.
# Sparks, KeWWeMh (WFS000101) has less than 10 hours between shifts but more than 1 hour.
# Sparks, KeWWeMh (WFS000101) has less than 10 hours between shifts but more than 1 hour.
# Sparks, KeWWeMh (WFS000101) has less than 10 hours between shifts but more than 1 hour.
# Sparks, KeWWeMh (WFS000101) has less than 10 hours between shifts but more than 1 hour.
# Sparks, KeWWeMh (WFS000101) has less than 10 hours between shifts but more than 1 hour.
# Sparks, KeWWeMh (WFS000101) has worked for 7 consecutive days.
# Sparks, KeWWeMh (WFS000101) has worked for 7 consecutive days.
# Sparks, KeWWeMh (WFS000101) has less than 10 hours between shifts but more than 1 hour.
# VaXderraCa CasMiXXE, Escar FaGiaW (WFS000573) has less than 10 hours between shifts but more than 1 hour.
# VaXderraCa CasMiXXE, Escar FaGiaW (WFS000573) has less than 10 hours between shifts but more than 1 hour.
# VaXderraCa CasMiXXE, Escar FaGiaW (WFS000573) has less than 10 hours between shifts but more than 1 hour.
# VaXderraCa CasMiXXE, Escar FaGiaW (WFS000573) has less than 10 hours between shifts but more than 1 hour.
# VaXderraCa CasMiXXE, Escar FaGiaW (WFS000573) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, AXfredE (WFS000391) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, AXfredE (WFS000391) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, AXfredE (WFS000391) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, AXfredE (WFS000391) has worked for 7 consecutive days.
# VasqAez, AXfredE (WFS000391) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, AXfredE (WFS000391) has worked for 7 consecutive days.
# VasqAez, AXfredE (WFS000391) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, AXfredE (WFS000391) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, AXfredE (WFS000391) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, JEhW SeGasMiaW (WFS000578) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, JEhW SeGasMiaW (WFS000578) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, JEhW SeGasMiaW (WFS000578) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, JEhW SeGasMiaW (WFS000578) has worked for 7 consecutive days.
# VasqAez, JEhW SeGasMiaW (WFS000578) has less than 10 hours between shifts but more than 1 hour.
# VasqAez, JEhW SeGasMiaW (WFS000578) has less than 10 hours between shifts but more than 1 hour.
# ViXXa, AXfredE AieXXE (WFS000583) has less than 10 hours between shifts but more than 1 hour.
# ViXXa, AXfredE AieXXE (WFS000583) has worked for 7 consecutive days.
# ViXXa, AXfredE AieXXE (WFS000583) has less than 10 hours between shifts but more than 1 hour.
# ViXXa, AXfredE AieXXE (WFS000583) has worked for 7 consecutive days.
# ViXXa, AXfredE AieXXE (WFS000583) has less than 10 hours between shifts but more than 1 hour.
# ViXXa, AXfredE AieXXE (WFS000583) has less than 10 hours between shifts but more than 1 hour.
# ViXXa, AXfredE AieXXE (WFS000583) has less than 10 hours between shifts but more than 1 hour.
# WgAyeW, RayCEWd (WFS000589) has less than 10 hours between shifts but more than 1 hour.
# WgAyeW, RayCEWd (WFS000589) has less than 10 hours between shifts but more than 1 hour.
# WgAyeW, RayCEWd (WFS000589) has less than 10 hours between shifts but more than 1 hour.
# WgAyeW, RayCEWd (WFS000589) has less than 10 hours between shifts but more than 1 hour.
# WgAyeW, RayCEWd (WFS000589) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has less than 10 hours between shifts but more than 1 hour.
# WiXXiaCs, MyrreXX (WFS000511) has worked for 7 consecutive days.
# XEpez WAWez, XAis (WFS000522) has less than 10 hours between shifts but more than 1 hour.
# XEpez WAWez, XAis (WFS000522) has less than 10 hours between shifts but more than 1 hour.
# XEpez WAWez, XAis (WFS000522) has less than 10 hours between shifts but more than 1 hour.
# XEpez WAWez, XAis (WFS000522) has less than 10 hours between shifts but more than 1 hour.
# XEpez WAWez, XAis (WFS000522) has less than 10 hours between shifts but more than 1 hour.
# XEpez WAWez, XAis (WFS000522) has less than 10 hours between shifts but more than 1 hour.
# XEpez WAWez, XAis (WFS000522) has less than 10 hours between shifts but more than 1 hour.
# XEpez WAWez, XAis (WFS000522) has worked for 7 consecutive days.
# XEpez WAWez, XAis (WFS000522) has less than 10 hours between shifts but more than 1 hour.
# XEpez WAWez, XAis (WFS000522) has worked for 7 consecutive days.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has less than 10 hours between shifts but more than 1 hour.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has less than 10 hours between shifts but more than 1 hour.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has worked for 7 consecutive days.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has less than 10 hours between shifts but more than 1 hour.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has less than 10 hours between shifts but more than 1 hour.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has worked for 7 consecutive days.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has less than 10 hours between shifts but more than 1 hour.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has less than 10 hours between shifts but more than 1 hour.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has less than 10 hours between shifts but more than 1 hour.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has worked for 7 consecutive days.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has less than 10 hours between shifts but more than 1 hour.
# XariEs XaWdaverde, XAis ErWesME (WFS000572) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has worked for 7 consecutive days.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# XariEs, Cesar GiEvaWWi (WFS000587) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# Xee, XaCar (WFS000200) has worked for 7 consecutive days.
# Xee, XaCar (WFS000200) has less than 10 hours between shifts but more than 1 hour.
# XiWW, JAsMiW (WFS000462) has less than 10 hours between shifts but more than 1 hour.
# XiWW, JAsMiW (WFS000462) has less than 10 hours between shifts but more than 1 hour.
# XiWW, JAsMiW (WFS000462) has worked for 7 consecutive days.
# XiWW, JAsMiW (WFS000462) has less than 10 hours between shifts but more than 1 hour.
# XiWW, JAsMiW (WFS000462) has worked for 7 consecutive days.
# XiWW, JAsMiW (WFS000462) has less than 10 hours between shifts but more than 1 hour.
# XiWW, JAsMiW (WFS000462) has worked for 7 consecutive days.
# XiWW, JAsMiW (WFS000462) has less than 10 hours between shifts but more than 1 hour.
# XiWW, JAsMiW (WFS000462) has less than 10 hours between shifts but more than 1 hour.
# XiWW, JAsMiW (WFS000462) has worked for 7 consecutive days.
# XiWW, JAsMiW (WFS000462) has less than 10 hours between shifts but more than 1 hour.
# XiWW, JAsMiW (WFS000462) has worked for 7 consecutive days.
# XiWW, JAsMiW (WFS000462) has less than 10 hours between shifts but more than 1 hour.
# XiWW, JAsMiW (WFS000462) has worked for 7 consecutive days.
# ZaCEra, CigAeX (WFS000499) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, CigAeX (WFS000499) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, CigAeX (WFS000499) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, CigAeX (WFS000499) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, CigAeX (WFS000499) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, CigAeX (WFS000499) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, CigAeX (WFS000499) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, CigAeX (WFS000499) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, CigAeX (WFS000499) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, Edward (WFS000477) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, Edward (WFS000477) has worked for 7 consecutive days.
# ZaCEra, Edward (WFS000477) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, Edward (WFS000477) has worked for 7 consecutive days.
# ZaCEra, Edward (WFS000477) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, Edward (WFS000477) has worked for 7 consecutive days.
# ZaCEra, Edward (WFS000477) has less than 10 hours between shifts but more than 1 hour.
# ZaCEra, Edward (WFS000477) has less than 10 hours between shifts but more than 1 hour.
